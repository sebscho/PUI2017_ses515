# %%
SQL_SOURCE = 'https://ses515.carto.com/api/v2/sql?q='

import urllib2
import urllib
import StringIO
import ast
import pandas as pd

def queryCartoDB(query, format='CSV', source=SQL_SOURCE):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    data = urllib.urlencode({'format': format, 'q': query})
    try:
        response = urllib2.urlopen(source, data)
    except urllib2.HTTPError, e:
        raise ValueError('\n'.join(ast.literal_eval(e.readline())['error']))
    except Exception:
        raise
    return response.read()

# %%
test = '''
SELECT *
FROM citibike
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(test)), sep=',')
# Out:
#        cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0            5960       NaN                   NaN       1      1965.0   19217
# 1            9806       NaN                   NaN       1      1971.0   17575
# 2           13113       NaN                   NaN       1      1973.0   20313
# 3               1       NaN                   NaN       2      1978.0   17131
# 4               2       NaN                   NaN       1      1993.0   21289
# 5               3       NaN                   NaN       2      1969.0   18903
# 6               4       NaN                   NaN       2      1985.0   21044
# 7               5       NaN                   NaN       1      1957.0   19868
# 8               6       NaN                   NaN       1      1979.0   15854
# 9               7       NaN                   NaN       1      1983.0   15173
# 10              8       NaN                   NaN       1      1955.0   17862
# ...

# %% [markdown]
# # Task one
# Sort by station id, and show top 10 records

# %%
task_one = '''
SELECT * FROM citibike
WHERE tripduration<10800
ORDER BY start_station_id DESC
LIMIT 10
'''

# %%
pd.read_csv(StringIO.StringIO(queryCartoDB(task_one)), sep=',')
# Out:
#    cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0        1228       NaN                   NaN       0         NaN   17849
# 1        1863       NaN                   NaN       1      1996.0   19309
# 2        1472       NaN                   NaN       2      1980.0   16987
# 3        1506       NaN                   NaN       0         NaN   21202
# 4        1587       NaN                   NaN       1      1959.0   15748
# 5        1628       NaN                   NaN       1      1980.0   20901
# 6         293       NaN                   NaN       2      1980.0   19484
# 7        1333       NaN                   NaN       0         NaN   18288
# 8        2205       NaN                   NaN       1      1979.0   17004
# 9        2026       NaN                   NaN       2      1984.0   18386
#
#    end_station_id  start_station_id  tripduration    usertype  \
# 0             525              3002          1900    Customer
# ...

# %% [markdown]
# # Task two
# Working with date time

# %%
# selecting trips starting on Feb 2 only
task_2a = '''
SELECT * FROM citibike
WHERE starttime >=  '2015-02-02 00:00'
AND starttime < '2015-02-03 00:00'
'''
pd.read_csv(StringIO.StringIO(queryCartoDB(task_2a)), sep=',')
# Out:
#       cartodb_id  the_geom  the_geom_webmercator  gender  birth_year  bikeid  \
# 0           6442       NaN                   NaN       1      1992.0   20684
# 1           6443       NaN                   NaN       2      1964.0   16094
# 2           6444       NaN                   NaN       1      1974.0   17362
# 3           6445       NaN                   NaN       2      1992.0   15475
# 4           6446       NaN                   NaN       1      1968.0   16272
# 5           6447       NaN                   NaN       1      1979.0   16370
# 6           6448       NaN                   NaN       1      1963.0   19437
# 7           6449       NaN                   NaN       1      1982.0   21211
# 8           6450       NaN                   NaN       2      1978.0   21417
# 9           6451       NaN                   NaN       1      1956.0   15722
# 10          6452       NaN                   NaN       1      1962.0   18972
# ...

# %%
# select average trip duration on the weekends
task_2b = '''

SELECT AVG(tripduration)
FROM citibike
WHERE extract(DOW FROM starttime) in (0,6)
'''
pd.read_csv(StringIO.StringIO(queryCartoDB(task_2b)), sep=',')
# Out:
#           avg  Unnamed: 1
# 0  662.942181         NaN

# %%
# select average trip duration on the weekends
task_2c = '''

SELECT AVG(tripduration)
FROM citibike
WHERE extract(DOW FROM starttime) not in (0,6)
'''

# rides are longer on the weekends
pd.read_csv(StringIO.StringIO(queryCartoDB(task_2c)), sep=',')
# Out:
#           avg  Unnamed: 1
# 0  681.052292         NaN

# %% [markdown]
# # Task 3
# Working with space

# %%
# list of start station location

task_3a = '''
SELECT CDB_TransformToWebmercator(CDB_LatLng(start_station_latitude, start_station_longitude)) as the_geom 
FROM citibike
GROUP BY start_station_latitude, start_station_longitude
'''
pd.read_csv(StringIO.StringIO(queryCartoDB(task_3a)), sep=',')
# Out:
#                                               the_geom  Unnamed: 1
# 0    0101000020110F0000863F88A4096A5FC19D1DAFD5DFF1...         NaN
# 1    0101000020110F0000BB2EC9F82D6A5FC19150E1B461FB...         NaN
# 2    0101000020110F0000D62721D3CA6D5FC157A5D529F6F5...         NaN
# 3    0101000020110F000060197671C96C5FC197A854AF46FA...         NaN
# 4    0101000020110F0000993A68067B6C5FC1B222DA492BFA...         NaN
# 5    0101000020110F00004FF9F3E90D6D5FC1F284479FC8F9...         NaN
# 6    0101000020110F00003816CC930D6B5FC17B393D28A0F9...         NaN
# 7    0101000020110F00006B6C9CBF186A5FC109C57CA0D8FC...         NaN
# 8    0101000020110F00008B8D725EB16B5FC1BF41718A0DF6...         NaN
# 9    0101000020110F0000BA97F1D5D36C5FC13D326BC3E4F5...         NaN
# 10   0101000020110F000052716DFB7B6D5FC1634AEE724BF4...         NaN
# 11   0101000020110F000079B8DA32AB685FC194DBF126F9F4...         NaN
# 12   0101000020110F000004115CC3E56B5FC1D8A47A41AFF7...         NaN
# ...

# %%
# show number of trips at each starting location
task_3b = '''
SELECT CDB_TransformToWebmercator(CDB_LatLng(start_station_latitude, start_station_longitude)) as the_geom_webmercator,
	MIN(cartodb_id) as cartodb_id,
    COUNT(tripduration) as numtrips
FROM citibike
GROUP BY start_station_latitude, start_station_longitude
'''
pd.read_csv(StringIO.StringIO(queryCartoDB(task_3b)), sep=',')
# Out:
#                                   the_geom_webmercator  cartodb_id  numtrips
# 0    0101000020110F0000863F88A4096A5FC19D1DAFD5DFF1...          84        54
# 1    0101000020110F0000BB2EC9F82D6A5FC19150E1B461FB...         412       486
# 2    0101000020110F0000D62721D3CA6D5FC157A5D529F6F5...         516       200
# 3    0101000020110F000060197671C96C5FC197A854AF46FA...         359       281
# 4    0101000020110F0000993A68067B6C5FC1B222DA492BFA...          78       218
# 5    0101000020110F00004FF9F3E90D6D5FC1F284479FC8F9...        1019       178
# 6    0101000020110F00003816CC930D6B5FC17B393D28A0F9...         110       288
# 7    0101000020110F00006B6C9CBF186A5FC109C57CA0D8FC...           7       164
# 8    0101000020110F00008B8D725EB16B5FC1BF41718A0DF6...         460       156
# 9    0101000020110F0000BA97F1D5D36C5FC13D326BC3E4F5...         799        82
# 10   0101000020110F000052716DFB7B6D5FC1634AEE724BF4...        5444        60
# ...

# %%
# show max and average trip times for stations within 500 ft of Times Square

task_3c = ''' 

SELECT CDB_TransformToWebmercator(CDB_LatLng(start_station_latitude, start_station_longitude)) as the_geom_webmercator,
	MIN(cartodb_id) as cartodb_id,
    AVG(tripduration) AVG_TRIP
    
    FROM citibike

    WHERE ST_DWithin(
  		CDB_LatLng(start_station_latitude,
                   start_station_longitude)::geography,
  		CDB_LatLng(40.7577, -73.9857)::geography,
  		500) AND extract(DOW FROM starttime) not in (0,6)

    GROUP BY start_station_latitude, start_station_longitude

    ORDER BY AVG_TRIP DESC
'''

# The ordered list shows the top average trip time in position 0
pd.read_csv(StringIO.StringIO(queryCartoDB(task_3c)), sep=',')
# Out:
#                                 the_geom_webmercator  cartodb_id    avg_trip
# 0  0101000020110F00001607D538556B5FC119A6CA6F41FC...        7341  727.876289
# 1  0101000020110F00003F9300B2976B5FC1B8B88F3102FC...        6468  676.274611
# 2  0101000020110F0000F55695027D6B5FC186E5BB69D7FB...        6446  654.350230
# 3  0101000020110F000004AF971C1D6B5FC17A48F3C1A8FB...        6740  642.711009
# 4  0101000020110F0000F22A632FBE6A5FC1363A28CFADFB...        7250  603.343137
# 5  0101000020110F00009BB87D02B76A5FC146C144E9E5FB...        6970  563.674603
# 6  0101000020110F000020D6742CE16A5FC112F4D73D73FC...        7263  511.751515
